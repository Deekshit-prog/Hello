# %%
import polars as pl

# %%
(ggplot(gapminder)
  + aes(x="continent", y="lifeExp", color="Continent")
  + geom_boxplot()
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_287/3232471653.py in <cell line: 0>()
# ----> 1 (ggplot(gapminder)
#       2   + aes(x="continent", y="lifeExp", color="Continent")
#       3   + geom_boxplot()
#       4 )
#
# NameError: name 'ggplot' is not defined

# %%
from plotnine import *

# %%
gapminder.head(5)
# Out:
# shape: (5, 6)
# ┌─────────────┬───────────┬──────┬─────────┬──────────┬────────────┐
# │ country     ┆ continent ┆ year ┆ lifeExp ┆ pop      ┆ gdpPercap  │
# │ ---         ┆ ---       ┆ ---  ┆ ---     ┆ ---      ┆ ---        │
# │ str         ┆ str       ┆ i64  ┆ f64     ┆ i64      ┆ f64        │
# ╞═════════════╪═══════════╪══════╪═════════╪══════════╪════════════╡
# │ Afghanistan ┆ Asia      ┆ 1952 ┆ 28.801  ┆ 8425333  ┆ 779.445314 │
# │ Afghanistan ┆ Asia      ┆ 1957 ┆ 30.332  ┆ 9240934  ┆ 820.85303  │
# │ Afghanistan ┆ Asia      ┆ 1962 ┆ 31.997  ┆ 10267083 ┆ 853.10071  │
# │ Afghanistan ┆ Asia      ┆ 1967 ┆ 34.02   ┆ 11537966 ┆ 836.197138 │
# │ Afghanistan ┆ Asia      ┆ 1972 ┆ 36.088  ┆ 13079460 ┆ 739.981106 │
# └─────────────┴───────────┴──────┴─────────┴──────────┴────────────┘

# %%
gapminder_short = gapminder.head(5)
gapminder_short
# Out:
# shape: (5, 6)
# ┌─────────────┬───────────┬──────┬─────────┬──────────┬────────────┐
# │ country     ┆ continent ┆ year ┆ lifeExp ┆ pop      ┆ gdpPercap  │
# │ ---         ┆ ---       ┆ ---  ┆ ---     ┆ ---      ┆ ---        │
# │ str         ┆ str       ┆ i64  ┆ f64     ┆ i64      ┆ f64        │
# ╞═════════════╪═══════════╪══════╪═════════╪══════════╪════════════╡
# │ Afghanistan ┆ Asia      ┆ 1952 ┆ 28.801  ┆ 8425333  ┆ 779.445314 │
# │ Afghanistan ┆ Asia      ┆ 1957 ┆ 30.332  ┆ 9240934  ┆ 820.85303  │
# │ Afghanistan ┆ Asia      ┆ 1962 ┆ 31.997  ┆ 10267083 ┆ 853.10071  │
# │ Afghanistan ┆ Asia      ┆ 1967 ┆ 34.02   ┆ 11537966 ┆ 836.197138 │
# │ Afghanistan ┆ Asia      ┆ 1972 ┆ 36.088  ┆ 13079460 ┆ 739.981106 │
# └─────────────┴───────────┴──────┴─────────┴──────────┴────────────┘

# %%
(gapminder
  .head(5)
)
# Out:
# shape: (5, 6)
# ┌─────────────┬───────────┬──────┬─────────┬──────────┬────────────┐
# │ country     ┆ continent ┆ year ┆ lifeExp ┆ pop      ┆ gdpPercap  │
# │ ---         ┆ ---       ┆ ---  ┆ ---     ┆ ---      ┆ ---        │
# │ str         ┆ str       ┆ i64  ┆ f64     ┆ i64      ┆ f64        │
# ╞═════════════╪═══════════╪══════╪═════════╪══════════╪════════════╡
# │ Afghanistan ┆ Asia      ┆ 1952 ┆ 28.801  ┆ 8425333  ┆ 779.445314 │
# │ Afghanistan ┆ Asia      ┆ 1957 ┆ 30.332  ┆ 9240934  ┆ 820.85303  │
# │ Afghanistan ┆ Asia      ┆ 1962 ┆ 31.997  ┆ 10267083 ┆ 853.10071  │
# │ Afghanistan ┆ Asia      ┆ 1967 ┆ 34.02   ┆ 11537966 ┆ 836.197138 │
# │ Afghanistan ┆ Asia      ┆ 1972 ┆ 36.088  ┆ 13079460 ┆ 739.981106 │
# └─────────────┴───────────┴──────┴─────────┴──────────┴────────────┘

# %%
gapminder_short = (gapminder
  .head(5)
)

# %%
(gapminder
  .select(
    pl.col("country"),
    pl.col("year").alias("measure_year"),
    pl.col("pop").alias("total_pop")
  )
)
# Out:
# shape: (1_704, 3)
# ┌─────────────┬──────────────┬───────────┐
# │ country     ┆ measure_year ┆ total_pop │
# │ ---         ┆ ---          ┆ ---       │
# │ str         ┆ i64          ┆ i64       │
# ╞═════════════╪══════════════╪═══════════╡
# │ Afghanistan ┆ 1952         ┆ 8425333   │
# │ Afghanistan ┆ 1957         ┆ 9240934   │
# │ Afghanistan ┆ 1962         ┆ 10267083  │
# │ Afghanistan ┆ 1967         ┆ 11537966  │
# │ Afghanistan ┆ 1972         ┆ 13079460  │
# │ …           ┆ …            ┆ …         │
# │ Zimbabwe    ┆ 1987         ┆ 9216418   │
# │ Zimbabwe    ┆ 1992         ┆ 10704340  │
# │ Zimbabwe    ┆ 1997         ┆ 11404948  │
# │ Zimbabwe    ┆ 2002         ┆ 11926563  │
# │ Zimbabwe    ┆ 2007         ┆ 12311143  │
# └─────────────┴──────────────┴───────────┘

# %%
(gapminder
  .select(
    pl.col("lifeExp").alias("life_expectancy"),
    pl.col("gdpPercap").alias("gdp_per_capita")
  )
)
# Out:
# shape: (1_704, 2)
# ┌─────────────────┬────────────────┐
# │ life_expectancy ┆ gdp_per_capita │
# │ ---             ┆ ---            │
# │ f64             ┆ f64            │
# ╞═════════════════╪════════════════╡
# │ 28.801          ┆ 779.445314     │
# │ 30.332          ┆ 820.85303      │
# │ 31.997          ┆ 853.10071      │
# │ 34.02           ┆ 836.197138     │
# │ 36.088          ┆ 739.981106     │
# │ …               ┆ …              │
# │ 62.351          ┆ 706.157306     │
# │ 60.377          ┆ 693.420786     │
# │ 46.809          ┆ 792.44996      │
# │ 39.989          ┆ 672.038623     │
# │ 43.487          ┆ 469.709298     │
# └─────────────────┴────────────────┘

# %%
(gapminder
    .filter(
        (pl.col("country") == "France") &
        (pl.col("year") == 1982)
    )
)
# Out:
# shape: (1, 6)
# ┌─────────┬───────────┬──────┬─────────┬──────────┬─────────────┐
# │ country ┆ continent ┆ year ┆ lifeExp ┆ pop      ┆ gdpPercap   │
# │ ---     ┆ ---       ┆ ---  ┆ ---     ┆ ---      ┆ ---         │
# │ str     ┆ str       ┆ i64  ┆ f64     ┆ i64      ┆ f64         │
# ╞═════════╪═══════════╪══════╪═════════╪══════════╪═════════════╡
# │ France  ┆ Europe    ┆ 1982 ┆ 74.89   ┆ 54433565 ┆ 20293.89746 │
# └─────────┴───────────┴──────┴─────────┴──────────┴─────────────┘

# %%
gapminder_upper = (gapminder
    .with_columns(country_upper = pl.col("country").str.to_uppercase())
)

# %%
(gapminder
  .with_columns(gdp_total = pl.col("pop") * pl.col("gdpPercap"))
)
# Out:
# shape: (1_704, 7)
# ┌─────────────┬───────────┬──────┬─────────┬──────────┬────────────┬───────────┐
# │ country     ┆ continent ┆ year ┆ lifeExp ┆ pop      ┆ gdpPercap  ┆ gdp_total │
# │ ---         ┆ ---       ┆ ---  ┆ ---     ┆ ---      ┆ ---        ┆ ---       │
# │ str         ┆ str       ┆ i64  ┆ f64     ┆ i64      ┆ f64        ┆ f64       │
# ╞═════════════╪═══════════╪══════╪═════════╪══════════╪════════════╪═══════════╡
# │ Afghanistan ┆ Asia      ┆ 1952 ┆ 28.801  ┆ 8425333  ┆ 779.445314 ┆ 6.5671e9  │
# │ Afghanistan ┆ Asia      ┆ 1957 ┆ 30.332  ┆ 9240934  ┆ 820.85303  ┆ 7.5854e9  │
# │ Afghanistan ┆ Asia      ┆ 1962 ┆ 31.997  ┆ 10267083 ┆ 853.10071  ┆ 8.7589e9  │
# │ Afghanistan ┆ Asia      ┆ 1967 ┆ 34.02   ┆ 11537966 ┆ 836.197138 ┆ 9.6480e9  │
# │ Afghanistan ┆ Asia      ┆ 1972 ┆ 36.088  ┆ 13079460 ┆ 739.981106 ┆ 9.6786e9  │
# │ …           ┆ …         ┆ …    ┆ …       ┆ …        ┆ …          ┆ …         │
# │ Zimbabwe    ┆ Africa    ┆ 1987 ┆ 62.351  ┆ 9216418  ┆ 706.157306 ┆ 6.5082e9  │
# │ Zimbabwe    ┆ Africa    ┆ 1992 ┆ 60.377  ┆ 10704340 ┆ 693.420786 ┆ 7.4226e9  │
# │ Zimbabwe    ┆ Africa    ┆ 1997 ┆ 46.809  ┆ 11404948 ┆ 792.44996  ┆ 9.0379e9  │
# │ Zimbabwe    ┆ Africa    ┆ 2002 ┆ 39.989  ┆ 11926563 ┆ 672.038623 ┆ 8.0151e9  │
# │ Zimbabwe    ┆ Africa    ┆ 2007 ┆ 43.487  ┆ 12311143 ┆ 469.709298 ┆ 5.7827e9  │
# └─────────────┴───────────┴──────┴─────────┴──────────┴────────────┴───────────┘

# %%
(gapminder
    .with_columns(country_upper = pl.col("country").str.to_uppercase())
)
# Out:
# shape: (1_704, 7)
# ┌─────────────┬───────────┬──────┬─────────┬──────────┬────────────┬───────────────┐
# │ country     ┆ continent ┆ year ┆ lifeExp ┆ pop      ┆ gdpPercap  ┆ country_upper │
# │ ---         ┆ ---       ┆ ---  ┆ ---     ┆ ---      ┆ ---        ┆ ---           │
# │ str         ┆ str       ┆ i64  ┆ f64     ┆ i64      ┆ f64        ┆ str           │
# ╞═════════════╪═══════════╪══════╪═════════╪══════════╪════════════╪═══════════════╡
# │ Afghanistan ┆ Asia      ┆ 1952 ┆ 28.801  ┆ 8425333  ┆ 779.445314 ┆ AFGHANISTAN   │
# │ Afghanistan ┆ Asia      ┆ 1957 ┆ 30.332  ┆ 9240934  ┆ 820.85303  ┆ AFGHANISTAN   │
# │ Afghanistan ┆ Asia      ┆ 1962 ┆ 31.997  ┆ 10267083 ┆ 853.10071  ┆ AFGHANISTAN   │
# │ Afghanistan ┆ Asia      ┆ 1967 ┆ 34.02   ┆ 11537966 ┆ 836.197138 ┆ AFGHANISTAN   │
# │ Afghanistan ┆ Asia      ┆ 1972 ┆ 36.088  ┆ 13079460 ┆ 739.981106 ┆ AFGHANISTAN   │
# │ …           ┆ …         ┆ …    ┆ …       ┆ …        ┆ …          ┆ …             │
# │ Zimbabwe    ┆ Africa    ┆ 1987 ┆ 62.351  ┆ 9216418  ┆ 706.157306 ┆ ZIMBABWE      │
# │ Zimbabwe    ┆ Africa    ┆ 1992 ┆ 60.377  ┆ 10704340 ┆ 693.420786 ┆ ZIMBABWE      │
# │ Zimbabwe    ┆ Africa    ┆ 1997 ┆ 46.809  ┆ 11404948 ┆ 792.44996  ┆ ZIMBABWE      │
# │ Zimbabwe    ┆ Africa    ┆ 2002 ┆ 39.989  ┆ 11926563 ┆ 672.038623 ┆ ZIMBABWE      │
# │ Zimbabwe    ┆ Africa    ┆ 2007 ┆ 43.487  ┆ 12311143 ┆ 469.709298 ┆ ZIMBABWE      │
# └─────────────┴───────────┴──────┴─────────┴──────────┴────────────┴───────────────┘

# %%
gapminder_upper = (gapminder
    .with_columns(country_upper = pl.col("country").str.to_uppercase())
)

# %%
gapminder_upper
# Out:
# shape: (1_704, 7)
# ┌─────────────┬───────────┬──────┬─────────┬──────────┬────────────┬───────────────┐
# │ country     ┆ continent ┆ year ┆ lifeExp ┆ pop      ┆ gdpPercap  ┆ country_upper │
# │ ---         ┆ ---       ┆ ---  ┆ ---     ┆ ---      ┆ ---        ┆ ---           │
# │ str         ┆ str       ┆ i64  ┆ f64     ┆ i64      ┆ f64        ┆ str           │
# ╞═════════════╪═══════════╪══════╪═════════╪══════════╪════════════╪═══════════════╡
# │ Afghanistan ┆ Asia      ┆ 1952 ┆ 28.801  ┆ 8425333  ┆ 779.445314 ┆ AFGHANISTAN   │
# │ Afghanistan ┆ Asia      ┆ 1957 ┆ 30.332  ┆ 9240934  ┆ 820.85303  ┆ AFGHANISTAN   │
# │ Afghanistan ┆ Asia      ┆ 1962 ┆ 31.997  ┆ 10267083 ┆ 853.10071  ┆ AFGHANISTAN   │
# │ Afghanistan ┆ Asia      ┆ 1967 ┆ 34.02   ┆ 11537966 ┆ 836.197138 ┆ AFGHANISTAN   │
# │ Afghanistan ┆ Asia      ┆ 1972 ┆ 36.088  ┆ 13079460 ┆ 739.981106 ┆ AFGHANISTAN   │
# │ …           ┆ …         ┆ …    ┆ …       ┆ …        ┆ …          ┆ …             │
# │ Zimbabwe    ┆ Africa    ┆ 1987 ┆ 62.351  ┆ 9216418  ┆ 706.157306 ┆ ZIMBABWE      │
# │ Zimbabwe    ┆ Africa    ┆ 1992 ┆ 60.377  ┆ 10704340 ┆ 693.420786 ┆ ZIMBABWE      │
# │ Zimbabwe    ┆ Africa    ┆ 1997 ┆ 46.809  ┆ 11404948 ┆ 792.44996  ┆ ZIMBABWE      │
# │ Zimbabwe    ┆ Africa    ┆ 2002 ┆ 39.989  ┆ 11926563 ┆ 672.038623 ┆ ZIMBABWE      │
# │ Zimbabwe    ┆ Africa    ┆ 2007 ┆ 43.487  ┆ 12311143 ┆ 469.709298 ┆ ZIMBABWE      │
# └─────────────┴───────────┴──────┴─────────┴──────────┴────────────┴───────────────┘

# %%
(gapminder
  .group_by(
    pl.col("year"),
    pl.col("continent")
    )
  .agg(pl.col("pop").mean().alias("pop_average"))
)
# Out:
# shape: (60, 3)
# ┌──────┬───────────┬─────────────┐
# │ year ┆ continent ┆ pop_average │
# │ ---  ┆ ---       ┆ ---         │
# │ i64  ┆ str       ┆ f64         │
# ╞══════╪═══════════╪═════════════╡
# │ 1957 ┆ Asia      ┆ 4.7357e7    │
# │ 1962 ┆ Asia      ┆ 5.1405e7    │
# │ 1967 ┆ Asia      ┆ 5.7747e7    │
# │ 1992 ┆ Asia      ┆ 9.4948e7    │
# │ 2002 ┆ Asia      ┆ 1.0915e8    │
# │ …    ┆ …         ┆ …           │
# │ 1962 ┆ Oceania   ┆ 6.641759e6  │
# │ 1977 ┆ Oceania   ┆ 8.6195e6    │
# │ 1997 ┆ Oceania   ┆ 1.1120715e7 │
# │ 2002 ┆ Oceania   ┆ 1.1727e7    │
# │ 2007 ┆ Oceania   ┆ 1.2275e7    │
# └──────┴───────────┴─────────────┘

# %%
(gapminder
  .group_by(
    pl.col("year"),
    pl.col("continent")
    )
  .agg(pl.col("pop").std().alias("pop_std"))
)
# Out:
# shape: (60, 3)
# ┌──────┬───────────┬──────────┐
# │ year ┆ continent ┆ pop_std  │
# │ ---  ┆ ---       ┆ ---      │
# │ i64  ┆ str       ┆ f64      │
# ╞══════╪═══════════╪══════════╡
# │ 1992 ┆ Americas  ┆ 5.8109e7 │
# │ 1957 ┆ Oceania   ┆ 5.2914e6 │
# │ 1977 ┆ Americas  ┆ 4.7904e7 │
# │ 1997 ┆ Americas  ┆ 6.2033e7 │
# │ 1952 ┆ Asia      ┆ 1.1323e8 │
# │ …    ┆ …         ┆ …        │
# │ 1982 ┆ Oceania   ┆ 8.4666e6 │
# │ 1952 ┆ Europe    ┆ 1.7247e7 │
# │ 1962 ┆ Oceania   ┆ 5.8735e6 │
# │ 1972 ┆ Asia      ┆ 1.7409e8 │
# │ 2002 ┆ Americas  ┆ 6.5602e7 │
# └──────┴───────────┴──────────┘

# %%
import polars as pl
gapminder=pl.read_csv("https://raw.githubusercontent.com/damien-dupre/data/refs/heads/master/gapminder.csv")

# %%
from plotnine import *

# %%
(ggplot(gapminder)
  + aes(x="continent", y="lifeExp", color="continent")
  + geom_boxplot()
)
